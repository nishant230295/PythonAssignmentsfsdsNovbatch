# %% [markdown]
# Sol 1
# ![CamScanner%2012-14-2021%2018.48_19.jpg](attachment:CamScanner%2012-14-2021%2018.48_19.jpg)

# %% [markdown]
# this signifies it is true only when P(x)=0 or 1

# %% [markdown]
# Sol 2
# ![CamScanner%2012-14-2021%2018.48_20.jpg](attachment:CamScanner%2012-14-2021%2018.48_20.jpg)
