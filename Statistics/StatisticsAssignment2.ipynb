# %% [markdown]
# ##Sol 1
# As a given average rate in a particular duration is given poisson distribution is the appropriate choice

# %% [markdown]
# ##Sol 1
# As a given average rate in a particular duration is given poisson distribution is the appropriate choice
# ![assign2q1.PNG](attachment:assign2q1.PNG)

# %% [markdown]
# ##Sol 2
# Yes the distribution of X Y is same
# ![assign2q2.PNG](attachment:assign2q2.PNG)
