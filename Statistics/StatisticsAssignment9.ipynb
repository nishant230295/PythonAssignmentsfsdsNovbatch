# %% [markdown]
# ![CamScanner%2012-14-2021%2018.48_26%20%281%29.jpg](attachment:CamScanner%2012-14-2021%2018.48_26%20%281%29.jpg)

# %% [markdown]
# ![CamScanner%2012-14-2021%2018.48_27.jpg](attachment:CamScanner%2012-14-2021%2018.48_27.jpg)

# %% [markdown]
# Part c the term conditional independence will be more appropriate in the scenario as because general indepence terms
# can have some effect on second event like after winning the game i have an idea bout opponents rank scores so
# conditional independence is appropriate
